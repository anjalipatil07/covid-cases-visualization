# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:\Data Science Project 2\covid.csv")

# %%
data
# Out:
#                entity iso_code        date  \
# 0             Algeria      DZA  2020-07-17
# 1             Algeria      DZA  2020-07-17
# 2             Algeria      DZA  2020-07-18
# 3             Algeria      DZA  2020-07-18
# 4             Algeria      DZA  2020-07-20
# ...               ...      ...         ...
# 107381  United States      USA  2022-01-09
# 107382  United States      USA  2022-01-09
# 107383  United States      USA  2022-01-09
# 107384  United States      USA  2022-01-09
# 107385  United States      USA  2022-01-09
#
#                                          indicator       value
# 0                              Daily ICU occupancy      62.000
# 1                  Daily ICU occupancy per million       1.390
# 2                              Daily ICU occupancy      67.000
# 3                  Daily ICU occupancy per million       1.502
# 4                              Daily ICU occupancy      64.000
# ...                                            ...         ...
# ...

# %%
data.columns
# Out:
# Index(['entity', 'iso_code', 'date', 'indicator', 'value'], dtype='object')

# %%
sns.relplot(x="entity", y="value", data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="entity", y="value", kind='line', data=data )

# %%
sns.catplot(x="entity", y="value", data=data)

# %%
sns.scatterplot(x="entity", y ="value", data=data)
# Out:
# <AxesSubplot:xlabel='entity', ylabel='value'>
